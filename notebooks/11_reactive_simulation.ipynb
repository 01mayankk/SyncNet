# %% [markdown]
# # SyncNet Experiment 11 — Reactive Decision State Machine & Decay Simulation
#
# **Objective**: Demonstrate reactive decision support state machine transitions (`NORMAL`, `FLAGGED`, `THROTTLED`, `ESCALATED`, `DECAYING`, `APPEALED`) and test exponential decay dynamics over simulated time steps.
# **Inputs**: `data/features/cluster_results.json`
# **Outputs**: Simulation state logs and appeal workflow

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from scripts.reactive_simulator import run_reactive_simulation_demo

rsm_demo = run_reactive_simulation_demo()
print("Final Simulation State:", rsm_demo.state)
