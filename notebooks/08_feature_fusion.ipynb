# %% [markdown]
# # SyncNet Experiment 08 — Multimodal Feature Fusion GraphSAGE Model
#
# **Objective**: Concatenate 384-dim MiniLM text embeddings + 12-dim profile metrics into a 396-dim fused feature matrix, train GraphSAGE on GPU (`cuda:0`), and extract 64-dim structural node representations.
# **Inputs**: `behavioral_features.parquet`, `content_embeddings.parquet`, `graph_data.pt`
# **Outputs**: `models/feature_fusion_sage.pt`, `data/features/fused_node_embeddings.parquet`

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from scripts.train_feature_fusion import train_feature_fusion_model

fusion_results = train_feature_fusion_model()
print(fusion_results)
