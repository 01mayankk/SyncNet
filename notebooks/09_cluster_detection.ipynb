# %% [markdown]
# # SyncNet Experiment 09 — Cluster Coordination Detection & Scoring
#
# **Objective**: Perform graph cluster detection on structural node representations $Z_{node}$, calculate intra-cluster edge density, content similarity, and formulate Cluster Coordination Scores $S_{coord}(C_k)$.
# **Inputs**: `fused_node_embeddings.parquet`, `clean_edges.parquet`
# **Outputs**: `data/features/cluster_results.json`, `data/features/cluster_summary.parquet`

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from scripts.cluster_coordination import detect_clusters_and_score

clusters = detect_clusters_and_score()
print(f"Detected {len(clusters)} clusters.")
