# %% [markdown]
# # SyncNet Experiment 07 — PyG GraphSAGE Baseline Training & Evaluation
#
# **Objective**: Train a 2-layer GraphSAGE (`SAGEConv`) model on interaction topology and evaluate test set node classification performance.
# **Input**: `data/features/graph_data.pt`
# **Output**: `models/graphsage_baseline.pt`

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from scripts.train_graphsage_baseline import train_graphsage

sage_results = train_graphsage()
print(sage_results)
