# %% [markdown]
# # SyncNet Experiment 06 — PyG GCN Baseline Training & Evaluation
#
# **Objective**: Train a 2-layer Graph Convolutional Network (GCNConv) model on interaction topology and evaluate test set node classification performance.
# **Input**: `data/features/graph_data.pt`
# **Output**: `models/gcn_baseline.pt`

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from scripts.train_gcn_baseline import train_gcn

gcn_results = train_gcn()
print(gcn_results)
