# %% [markdown]
# # SyncNet Experiment 10 — Baseline Model Evaluation & Comparison
#
# **Objective**: Compare held-out test performance metrics across Behavioral Baselines, Content Embedding Baselines, and future GNN Graph models.
# **Inputs**: `data/features/behavioral_features.parquet`, `data/features/content_embeddings.parquet`

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

from scripts.train_baselines import train_and_evaluate_baselines

df_results = train_and_evaluate_baselines()
df_results
